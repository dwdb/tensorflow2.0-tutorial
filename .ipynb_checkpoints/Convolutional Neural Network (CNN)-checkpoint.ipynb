# %%
import tensorflow as tf
import os

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %% [markdown]
# ## Download and prepare the CIFAR10 dataset
# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 17s 348us/sample - loss: 1.5214 - accuracy: 0.4442 - val_loss: 1.2907 - val_accuracy: 0.5350
# Epoch 2/10
# 50000/50000 [==============================] - 14s 274us/sample - loss: 1.1330 - accuracy: 0.5990 - val_loss: 1.0467 - val_accuracy: 0.6310
# Epoch 3/10
# 50000/50000 [==============================] - 14s 277us/sample - loss: 0.9784 - accuracy: 0.6576 - val_loss: 0.9743 - val_accuracy: 0.6571
# Epoch 4/10
# 50000/50000 [==============================] - 14s 283us/sample - loss: 0.8906 - accuracy: 0.6892 - val_loss: 0.9166 - val_accuracy: 0.6793
# Epoch 5/10
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.8210 - accuracy: 0.7128 - val_loss: 0.8916 - val_accuracy: 0.6861
# Epoch 6/10
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.7632 - accuracy: 0.7327 - val_loss: 0.8851 - val_accuracy: 0.6958
# Epoch 7/10
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.7152 - accuracy: 0.7486 - val_loss: 0.8734 - val_accuracy: 0.6997
# Epoch 8/10
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.6672 - accuracy: 0.7673 - val_loss: 0.9287 - val_accuracy: 0.6898
# Epoch 9/10
# 50000/50000 [==============================] - 14s 283us/sample - loss: 0.6273 - accuracy: 0.7806 - val_loss: 0.9032 - val_accuracy: 0.6968
# Epoch 10/10
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.5901 - accuracy: 0.7910 - val_loss: 0.9198 - val_accuracy: 0.6895

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/1 - 1s - loss: 0.9440 - accuracy: 0.6895
